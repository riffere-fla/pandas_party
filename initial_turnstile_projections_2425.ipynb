# %%
import pandas as pd
import numpy as np
from catnip.fla_redshift import FLA_Redshift
from sqlalchemy import null
from datetime import datetime

from prefect.blocks.system import Secret
from typing import Dict
from concurrent.futures import ThreadPoolExecutor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from catnip.fla_redshift import FLA_Redshift
#       4 from sqlalchemy import null
#       5 from datetime import datetime
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\catnip\fla_redshift.py:2
#       1 import pandas as pd
# ----> 2 from pandera import DataFrameModel
#       3 from pandera.typing import DataFrame
#       5 from pydantic import BaseModel, SecretStr
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\__init__.py:5
#       1 """A flexible and expressive pandas validation library."""
#       3 import platform
# ----> 5 import pandera.backends
#       6 import pandera.backends.base.builtin_checks
#       7 import pandera.backends.base.builtin_hypotheses
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\backends\__init__.py:4
#       1 """Pandera backends."""
#       3 # ensure that base builtin checks and hypothesis are registered
# ----> 4 import pandera.backends.base.builtin_checks
#       5 import pandera.backends.base.builtin_hypotheses
#       6 import pandera.backends.pandas
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\backends\base\builtin_checks.py:14
#      11 import re
#      12 from typing import Any, Iterable, Optional, TypeVar, Union
# ---> 14 from pandera.api.checks import Check
#      16 T = TypeVar("T")
#      19 @Check.register_builtin_check_fn
#      20 def equal_to(data: Any, value: Any) -> Any:
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\api\checks.py:17
#      15 from pandera import errors
#      16 from pandera.api.base.checks import BaseCheck, CheckResult
# ---> 17 from pandera.strategies.base_strategies import SearchStrategy
#      19 T = TypeVar("T")
#      22 # pylint: disable=too-many-public-methods
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\strategies\__init__.py:3
#       1 """Data synthesis strategies for pandera, powered by the hypothesis package."""
# ----> 3 from pandera.strategies.pandas_strategies import *
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\strategies\pandas_strategies.py:42
#      32 import pandas as pd
#      34 from pandera.dtypes import (
#      35     DataType,
#      36     is_category,
#    (...)
#      40     is_timedelta,
#      41 )
# ---> 42 from pandera.engines import numpy_engine, pandas_engine
#      43 from pandera.errors import BaseStrategyOnlyError, SchemaDefinitionError
#      44 from pandera.strategies.base_strategies import (
#      45     HAS_HYPOTHESIS,
#      46     STRATEGY_DISPATCHER,
#      47 )
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\pandera\engines\pandas_engine.py:757
#     738             is_python_string = data_container.map(lambda x: isinstance(x, str))  # type: ignore[operator]
#     739         return is_python_string.astype(bool) | data_container.isna()
#     742 Engine.register_dtype(
#     743     numpy_engine.Object,
#     744     equivalents=[
#     745         "object",
#     746         "object_",
#     747         "object0",
#     748         "O",
#     749         "bytes",
#     750         "mixed-integer",
#     751         "mixed",
#     752         "bytes",
#     753         bytes,
#     754         object,
#     755         np.object_,
#     756         np.bytes_,
# --> 757         np.string_,
#     758     ],
#     759 )
#     761 # ###############################################################################
#     762 # # time
#     763 # ###############################################################################
#     766 _PandasDatetime = Union[np.datetime64, pd.DatetimeTZDtype]
#
# File c:\Users\riffere\Documents\pandas_party\venv\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     raise AttributeError(__former_attrs__[attr], name=None)
#     413 if attr in __expired_attributes__:
# --> 414     raise AttributeError(
#     415         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     416         f"{__expired_attributes__[attr]}",
#     417         name=None
#     418     )
#     420 if attr == "chararray":
#     421     warnings.warn(
#     422         "`np.chararray` is deprecated and will be removed from "
#     423         "the main namespace in the future. Use an array with a string "
#     424         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.string_` was removed in the NumPy 2.0 release. Use `np.bytes_` instead.

# %%
def get_redshift_credentials() -> Dict:

    cred_dict = {
        "dbname": Secret.load("stellar-redshift-db-name").get(),
        "host": Secret.load("stellar-redshift-host").get(),
        "port": 5439,
        "user": Secret.load("stellar-redshift-user-name").get(),
        "password": Secret.load("stellar-redshift-password").get(),

        "aws_access_key_id": Secret.load("fla-s3-aws-access-key-id-east-1").get(),
        "aws_secret_access_key": Secret.load("fla-s3-aws-secret-access-key-east-1").get(),
        "bucket": Secret.load("fla-s3-bucket-name-east-1").get(),
        "subdirectory": "us-east-1",

        "verbose": False,
    }

    return cred_dict

with ThreadPoolExecutor(1) as pool:
    rs_creds = pool.submit(lambda: get_redshift_credentials()).result()

# %%
q = """
WITH historical AS (
    SELECT
        game_desc.season,
        game_desc.tier,
        ticket.event_date::date,
        ticket.comp_seats::float,
        ticket.paid_seats::float,
        CASE
            WHEN ticket.is_comp = TRUE AND ticket.did_attended = TRUE THEN 1
            ELSE 0
        END AS "comp_seats_attended",
        CASE
            WHEN is_comp = FALSE AND did_attended = TRUE THEN 1
            ELSE 0
        END AS "paid_seats_attended"
    FROM
        custom.cth_v_historical_ticket ticket
    INNER JOIN
        custom.cth_game_descriptions game_desc
            ON ticket.event_datetime::date = game_desc.event_datetime::date
            AND game_desc.season IN ('2021-22', '2022-23', '2023-24', '2024-25')
            AND game_desc.event_datetime < current_date
),
tier_show_rate AS (
    SELECT
        season,
        tier,
        sum(historical.comp_seats_attended)::float / sum(historical.comp_seats) AS "comp_show_rate",
        sum(historical.paid_seats_attended)::float / sum(historical.paid_seats) AS "paid_show_rate"
    FROM
        historical
    GROUP BY
        season, tier
)
SELECT * FROM tier_show_rate
"""

initial_df = FLA_Redshift(**rs_creds).query_warehouse(sql_string = q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 39
#       1 q = """
#       2 WITH historical AS (
#       3     SELECT
#    (...)
#      36 SELECT * FROM tier_show_rate
#      37 """
# ---> 39 initial_df = FLA_Redshift(**rs_creds).query_warehouse(sql_string = q)
#
# NameError: name 'FLA_Redshift' is not defined

# %%
weights = {'2021-22':0.5, '2022-23': .75, '2023-24':1.25,'2024-25':1.5}

initial_df['weights'] = initial_df['season'].map(weights)

def weighted_paid_average(group):
    # Calculate the weighted sum
    weighted_sum = (group['paid_show_rate'] * group['weights']).sum()
    
    # Calculate the weight sum
    weight_sum = group['weights'].sum()
    
    # Calculate the weighted average
    wavg = weighted_sum / weight_sum
    
    return pd.Series({
        'weighted_paid_average': wavg
    })

paid_tiers = initial_df.groupby('tier').apply(weighted_paid_average).reset_index()

def weighted_comp_average(group):
    # Calculate the weighted sum
    weighted_sum = (group['comp_show_rate'] * group['weights']).sum()
    
    # Calculate the weight sum
    weight_sum = group['weights'].sum()
    
    # Calculate the weighted average
    wavg = weighted_sum / weight_sum
    
    return pd.Series({
        'weighted_comp_average': wavg
    })

comp_tiers = initial_df.groupby('tier').apply(weighted_comp_average).reset_index()

tiers = pd.merge(paid_tiers, comp_tiers, on = 'tier', how = 'left')

# %%
q = """
select
    cth_v_ticket_2425.event_datetime,
    tier,
    datediff('days', current_date, cth_v_ticket_2425.event_datetime) as days_from_event,
    sum(paid_seats) as paid_seats,
    sum(comp_seats) as comp_seats
from
    custom.cth_v_ticket_2425
left join
    custom.cth_game_descriptions game_desc ON date(cth_v_ticket_2425.event_datetime) = date(game_desc.event_date)
group by
    cth_v_ticket_2425.event_datetime, tier
order by
    cth_v_ticket_2425.event_datetime
"""

current_df = FLA_Redshift(**rs_creds).query_warehouse(sql_string = q)

# %%
final_df = pd.merge(current_df, tiers, on = 'tier', how = 'left')

final_df['paid_attendance'] = final_df['paid_seats']*final_df['weighted_paid_average']
final_df['comp_attendance'] = final_df['comp_seats']*final_df['weighted_comp_average']
final_df['total_attendance'] = final_df['paid_attendance']+final_df['comp_attendance']

final_df
# Out:
#         event_datetime tier  days_from_event  paid_seats  comp_seats  \
# 0  2024-09-28 18:00:00   PS              -18       14313         456
# 1  2024-09-30 19:00:00   PS              -16       13634         421
# 2  2024-10-08 19:00:00    B               -8       19204         609
# 3  2024-10-17 19:00:00    E                1       16417         465
# 4  2024-10-19 18:00:00    D                3       18091         321
# 5  2024-10-22 18:30:00    E                6       15256         351
# 6  2024-11-02 18:00:00    F               17       12289        1507
# 7  2024-11-07 19:00:00    E               22       15640         318
# 8  2024-11-09 18:00:00    C               24       17957         298
# 9  2024-11-12 19:30:00    E               27       15232         322
# 10 2024-11-14 19:00:00    D               29       15094         322
# 11 2024-11-16 19:00:00    D               31       17219         298
# 12 2024-11-23 18:00:00    C               38       17094         298
# 13 2024-11-25 19:00:00    E               40       15053         338
# 14 2024-11-27 19:30:00    B               42       17127         298
# 15 2024-11-30 16:00:00    C               45       16947         298
# 16 2024-12-07 18:00:00    D               52       17117         302
# 17 2024-12-20 19:00:00    C               65       14598         298
# 18 2024-12-23 19:00:00    B               68       16931         298
# 19 2024-12-28 13:00:00    A               73       17444         298
# 20 2024-12-30 19:00:00    A               75       17430         298
# 21 2025-01-02 19:00:00    D               78       14522         318
# 22 2025-01-03 19:00:00    C               79       14823         298
# 23 2025-01-11 13:00:00    B               87       17573         348
# 24 2025-01-16 19:00:00    D               92       15087         320
# 25 2025-01-18 18:00:00    D               94       16877         298
# 26 2025-01-29 19:00:00    E              105       15473         318
# 27 2025-02-01 13:00:00    C              108       16996         298
# 28 2025-02-02 18:00:00    D              109       17069         298
# 29 2025-02-08 19:00:00    C              115       17269         298
# 30 2025-02-22 18:00:00    C              129       16963         298
# 31 2025-02-27 19:30:00    C              134       15471         298
# 32 2025-03-01 15:00:00    C              136       16952         404
# 33 2025-03-03 19:00:00    C              138       16901         298
# 34 2025-03-06 19:00:00    E              141       14719         318
# 35 2025-03-08 18:00:00    C              143       16877         298
# 36 2025-03-23 18:00:00    C              158       16883         298
# 37 2025-03-28 19:00:00    D              163       14163         318
# 38 2025-03-30 13:00:00    B              165       16809         298
# 39 2025-04-08 19:00:00    B              174       16862         298
# 40 2025-04-10 19:00:00    D              176       14623         318
# 41 2025-04-12 18:00:00    C              178       16656         298
# 42 2025-04-14 19:00:00    B              180       17018         298
#
#     weighted_paid_average  weighted_comp_average  paid_attendance  \
# 0                0.574348               0.448042      8220.637878
# 1                0.574348               0.448042      7830.655826
# 2                0.891159               0.704965     17113.814988
# 3                0.819578               0.667316     13455.017288
# 4                0.834918               0.698592     15104.494680
